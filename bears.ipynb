# %%
#hide
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
#hide
#hide_output
# !pip install voila
# !jupyter server extension enable --sys-prefix voila.server_extension
# Out:
# Requirement already satisfied: voila in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (0.5.8)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (8.6.3)
# Requirement already satisfied: jupyter-core>=4.11.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (5.8.1)
# Requirement already satisfied: jupyter-server<3,>=1.18 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (2.27.3)
# Requirement already satisfied: nbclient>=0.4.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (0.10.2)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (7.16.6)
# Requirement already satisfied: traitlets<6,>=5.0.3 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (5.14.3)
# Requirement already satisfied: websockets>=9.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from voila) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (26.4.0)
# Requirement already satisfied: tornado>=6.2 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.22.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.24.0)
# Requirement already satisfied: requests>=2.31 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (3.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (2.19.1)
# Requirement already satisfied: idna>=2.8 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (4.13.2)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (21.2.0)
# Requirement already satisfied: webencodings in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-core>=4.11.0->voila) (4.3.8)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.1)
# Requirement already satisfied: fqdn in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.5.1)
# Requirement already satisfied: isoduration in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.0.0)
# Requirement already satisfied: uri-template in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (24.11.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.18->voila) (2.21.1)
# Requirement already satisfied: six>=1.5 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2025.4.26)
# Requirement already satisfied: ptyprocess in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=1.18->voila) (0.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (1.17.1)
# Requirement already satisfied: pycparser in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (2.9.0.20250516)
# Extension package voila.server_extension took 0.1783s to import
# Enabling: voila.server_extension
# - Writing config: /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/etc/jupyter
#     - Validating voila.server_extension...
#       voila.server_extension  OK
#     - Extension successfully enabled.

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')
# Out:
# /Users/Christoph.Zwirello36/.local/share/virtualenvs/fastbook-9MqPMhTa/lib/python3.12/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %%
int(learn_inf.predict('images/grizzly.jpg')[1])
learn_inf.dls.vocab[int(learn_inf.predict('images/grizzly.jpg')[1])]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 'grizzly'

# %%
#hide_output
btn_upload = widgets.FileUpload()
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
#btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
#hide_output
btn_run = widgets.Button(description='Classify')
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
lbl_pred = widgets.Label()

# %%
out_pl = widgets.Output()

# %%
def on_click_classify(change):
    print(btn_upload)
    print(btn_upload.data[-1])
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
#hide_output
VBox([widgets.Label('Select your bear!'), 
     btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
